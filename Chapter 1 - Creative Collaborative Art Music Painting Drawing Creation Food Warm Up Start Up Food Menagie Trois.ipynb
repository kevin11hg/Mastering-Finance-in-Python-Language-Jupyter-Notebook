# %%
from IPython.lib.display import YouTubeVideo

# %%
YouTubeVideo('A7BDrAUKMQo')

# %%
import pandas as pd

# %%
from pandas_datareader import data
import datetime

# %%
start = datetime.datetime(2014,1,1)
end = datetime.datetime(2014,12,31)

# %%
df = data.DataReader("AAPL", 'yahoo', start, end)
df.head()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2014-01-02  19.893929  19.715000  19.845715  19.754642  234684800.0  17.481461
# 2014-01-03  19.775000  19.301071  19.745001  19.320715  392467600.0  17.097466
# 2014-01-06  19.528572  19.057142  19.194643  19.426071  412610800.0  17.190701
# 2014-01-07  19.498571  19.211428  19.440001  19.287144  317209200.0  17.067759
# 2014-01-08  19.484285  19.238928  19.243214  19.409286  258529600.0  17.175852

# %%
from IPython.display import Math

Math(r'N(x) \frac{1}{\sqrt{2\pi}}\int_{-\infty}^{x} e^{-\frac{z^2}{2}}\, dz')
# Out:
# $\displaystyle N(x) \frac{1}{\sqrt{2\pi}}\int_{-\infty}^{x} e^{-\frac{z^2}{2}}\, dz$

# %% [markdown]
# $$N(x) = \frac{1}{\sqrt{2\pi}}\int_{-infty}^{x} e^{-\frac{z^2}{2}}\, dz$$

# %% [markdown]
# ## Displaying Graphs

# %%
import numpy as np
import math
import matplotlib.pyplot as plt

x = np.linspace(0, 2*math.pi)
plt.plot(x, np.sin(x), label=r'$\sin(x)$')
plt.plot(x, np.cos(x), 'ro', label=r'$\cos(x)$')
plt.title(r'Two plots in a graph')
plt.legend()
# Out:
# Matplotlib is building the font cache; this may take a moment.
